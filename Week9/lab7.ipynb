# %%
# ================== IMPORT ==================
import nltk
import random
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, names, wordnet as wn
from nltk.probability import FreqDist
from nltk import bigrams
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# ================== DOWNLOAD DATA ==================
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('names')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\bhn20\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

languages = stopwords.fileids()
print(languages)
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# 1. Viết chương trình Python với thư viện NLTK để liệt kê các tên của copus.

# %%
import nltk
from nltk.corpus import gutenberg, stopwords, names

# liệt kê một số corpus phổ biến
print("Gutenberg:", gutenberg.fileids())
print("Names:", names.fileids())
print("Stopwords languages:", stopwords.fileids())
# Out:
# Gutenberg: ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# Names: ['female.txt', 'male.txt']
# Stopwords languages: ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# 2. Viết chương trình Python với thư viện NLTK để liệt kê danh sách các stopword bằng các
# ngôn ngữ khác nhau.

# %%
from nltk.corpus import stopwords

languages = stopwords.fileids()
print(languages)
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# 3. Viết chương trình Python với thư viện NLTK để kiểm tra danh sách các stopword bằng các
# ngôn ngữ khác nhau

# %%
for lang in stopwords.fileids():
    print(f"\nLanguage: {lang}")
    print(stopwords.words(lang)[:10])  # in 10 từ đầu
# Out:
# Language: albanian
# ['tyre', 'rreth', 'le', 'atyre', 'këta', 'megjithëse', 'kemi', 'per', 'ndonëse', 'dytë']
#
# Language: arabic
# ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي']
#
# Language: azerbaijani
# ['a', 'ad', 'altı', 'altmış', 'amma', 'arasında', 'artıq', 'ay', 'az', 'bax']
#
# Language: basque
# ['ahala', 'aitzitik', 'al', 'ala ', 'alabadere', 'alabaina', 'alabaina', 'aldiz ', 'alta', 'amaitu']
#
# Language: belarusian
# ['на', 'не', 'што', 'па', 'да', 'за', 'як', 'для', 'гэта', 'ад']
#
# Language: bengali
# ['অতএব', 'অথচ', 'অথবা', 'অনুযায়ী', 'অনেক', 'অনেকে', 'অনেকেই', 'অন্তত', 'অন্য', 'অবধি']
#
# Language: catalan
# ['a', 'abans', 'ací', 'ah', 'així', 'això', 'al', 'aleshores', 'algun', 'alguna']
#
# Language: chinese
# ['一', '一下', '一些', '一切', '一则', '一天', '一定', '一方面', '一旦', '一时']
#
# Language: danish
# ['og', 'i', 'jeg', 'det', 'at', 'en', 'den', 'til', 'er', 'som']
#
# Language: dutch
# ['de', 'en', 'van', 'ik', 'te', 'dat', 'die', 'in', 'een', 'hij']
#
# Language: english
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
#
# Language: finnish
# ['olla', 'olen', 'olet', 'on', 'olemme', 'olette', 'ovat', 'ole', 'oli', 'olisi']
#
# Language: french
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle']
#
# Language: german
# ['aber', 'alle', 'allem', 'allen', 'aller', 'alles', 'als', 'also', 'am', 'an']
#
# Language: greek
# ['αλλα', 'αν', 'αντι', 'απο', 'αυτα', 'αυτεσ', 'αυτη', 'αυτο', 'αυτοι', 'αυτοσ']
#
# Language: hebrew
# ['אני', 'את', 'אתה', 'אנחנו', 'אתן', 'אתם', 'הם', 'הן', 'היא', 'הוא']
#
# Language: hinglish
# ['a', 'aadi', 'aaj', 'aap', 'aapne', 'aata', 'aati', 'aaya', 'aaye', 'ab']
#
# Language: hungarian
# ['a', 'ahogy', 'ahol', 'aki', 'akik', 'akkor', 'alatt', 'által', 'általában', 'amely']
#
# Language: indonesian
# ['ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir']
#
# Language: italian
# ['ad', 'al', 'allo', 'ai', 'agli', 'all', 'agl', 'alla', 'alle', 'con']
#
# Language: kazakh
# ['ах', 'ох', 'эх', 'ай', 'эй', 'ой', 'тағы', 'тағыда', 'әрине', 'жоқ']
#
# Language: nepali
# ['छ', 'र', 'पनि', 'छन्', 'लागि', 'भएको', 'गरेको', 'भने', 'गर्न', 'गर्ने']
#
# Language: norwegian
# ['og', 'i', 'jeg', 'det', 'at', 'en', 'et', 'den', 'til', 'er']
#
# Language: portuguese
# ['a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as']
#
# Language: romanian
# ['a', 'abia', 'acea', 'aceasta', 'această', 'aceea', 'aceeasi', 'acei', 'aceia', 'acel']
#
# Language: russian
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со']
#
# Language: slovene
# ['ali', 'ampak', 'bodisi', 'in', 'kajti', 'marveč', 'namreč', 'ne', 'niti', 'oziroma']
#
# Language: spanish
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se']
#
# Language: swedish
# ['och', 'det', 'att', 'i', 'en', 'jag', 'hon', 'som', 'han', 'på']
#
# Language: tajik
# ['аз', 'дар', 'ба', 'бо', 'барои', 'бе', 'то', 'ҷуз', 'пеши', 'назди']
#
# Language: tamil
# ['அங்கு', 'அங்கே', 'அடுத்த', 'அதனால்', 'அதன்', 'அதற்கு', 'அதிக', 'அதில்', 'அது', 'அதே']
#
# Language: turkish
# ['acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz']
#
# Language: uzbek
# ['bu', 'bular', 'buning', 'buniki', 'buni', 'bundan', 'bunga', 'bunda', 'shu', 'shular']

# %% [markdown]
# 4. Viết chương trình Python với thư viện NLTK để loại bỏ các stopword từ một văn bản đã cho.

# %%
 

text = "I love studying artificial intelligence and machine learning"
tokens = word_tokenize(text)
stop_words = set(stopwords.words('english'))
filtered = [w for w in tokens if w.lower() not in stop_words]

print("Filtered:", filtered)
# Out:
# Filtered: ['love', 'studying', 'artificial', 'intelligence', 'machine', 'learning']

# %% [markdown]
# 5. Viết chương trình Python với thư viện NLTK bỏ qua các stopword từ danh sách các
# stopword.

# %%
from nltk.corpus import stopwords

words = ["I", "love", "AI", "and", "data", "science"]
stop_words = set(stopwords.words('english'))

filtered = list(filter(lambda w: w.lower() not in stop_words, words))
print(filtered)
# Out:
# ['love', 'AI', 'data', 'science']

# %% [markdown]
# 6. Viết một chương trình Python với thư viện NLTK để tìm định nghĩa và ví dụ của một từ đã
# cho bằng WordNet từ Wikipedia,

# %%
from nltk.corpus import wordnet as wn

word = "computer"

synsets = wn.synsets(word)

for syn in synsets[:2]:
    print("Definition:", syn.definition())
    print("Example:", syn.examples())
# Out:
# Definition: a machine for performing calculations automatically
# Example: []
# Definition: an expert at calculation (or at operating calculating machines)
# Example: []

# %% [markdown]
# 7. Viết chương trình Python với thư viện NLTK để tìm tập hợp các từ đồng nghĩa và trái nghĩa
# của một từ nào đó.

# %%
synonyms = []
antonyms = []

for syn in wn.synsets("good"):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

print("Synonyms:", set(synonyms))
print("Antonyms:", set(antonyms))
# Out:
# Synonyms: {'beneficial', 'salutary', 'thoroughly', 'in_effect', 'unspoiled', 'commodity', 'just', 'dependable', 'undecomposed', 'proficient', 'near', 'effective', 'respectable', 'practiced', 'in_force', 'dear', 'soundly', 'well', 'estimable', 'adept', 'unspoilt', 'skilful', 'honorable', 'goodness', 'ripe', 'honest', 'safe', 'skillful', 'good', 'full', 'trade_good', 'sound', 'serious', 'secure', 'right', 'upright', 'expert'}
# Antonyms: {'evilness', 'bad', 'badness', 'evil', 'ill'}

# %% [markdown]
# 8. Viết chương trình Python với thư viện NLTK để có cái nhìn tổng quan về bộ tag, chi tiết của
# một tag cụ thể trong bộ tag và chi tiết về một số bộ tag liên quan, sử dụng biểu thức chính
# quy

# %%
nltk.help.upenn_tagset('NN')

sentence = "The cat is running in the garden"
tokens = word_tokenize(sentence)

print("Words in sentence:")
for word in tokens:
    if re.match(r'^[A-Za-z]+$', word):
        print(word)
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# Words in sentence:
# The
# cat
# is
# running
# in
# the
# garden

# %% [markdown]
# 9. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai danh từ đã
# cho.

# %%
w1 = wn.synset('dog.n.01')
w2 = wn.synset('cat.n.01')

print("Similarity:", w1.wup_similarity(w2))
# Out:
# Similarity: 0.8571428571428571

# %% [markdown]
# 10. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai động từ đã
# cho.

# %%
v1 = wn.synset('run.v.01')
v2 = wn.synset('walk.v.01')

print("Similarity:", v1.wup_similarity(v2))
# Out:
# Similarity: 0.2857142857142857

# %% [markdown]
# 11. Viết chương trình Python với thư viện NLTK để tìm số lượng tên nam và nữ trong các tên
# kho ngữ liệu. In tên 10 nam và nữ đầu tiên. Lưu ý: Kho văn bản tên chứa tổng cộng khoảng
# 2943 nam (male.txt) và 5001 nữ (Female.txt) tên. Kho được biên soạn bởi Kantrowitz, Ross.

# %%
from nltk.corpus import names

male_names = names.words('male.txt')
female_names = names.words('female.txt')

print("Male count:", len(male_names))
print("Female count:", len(female_names))

print("First 10 male:", male_names[:10])
print("First 10 female:", female_names[:10])
# Out:
# Male count: 2943
# Female count: 5001
# First 10 male: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# First 10 female: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']

# %% [markdown]
# 12. Viết chương trình Python với thư viện NLTK để in 15 kết hợp ngẫu nhiên đầu tiên được gắn
# nhãn nam và được gắn nhãn tên nữ từ kho tên.

# %%
import random

male_sample = random.sample(male_names, 15)
female_sample = random.sample(female_names, 15)

print("Male sample:", male_sample)
print("Female sample:", female_sample)
# Out:
# Male sample: ['Lazarus', 'Worth', 'Raul', 'Earle', 'Jock', 'Riccardo', 'Hans', 'Addie', 'Jonny', 'Flinn', 'Prentice', 'Yanaton', 'Artur', 'Grace', 'Jordon']
# Female sample: ['Teane', 'Antonia', 'Rina', 'Zulema', 'Lucretia', 'Karina', 'Joya', 'Emelda', 'Cammie', 'Clarita', 'Phedra', 'Carolan', 'Fenelia', 'Philomena', 'Rosabel']

# %% [markdown]
# 13. Viết chương trình Python với thư viện NLTK để trích xuất ký tự cuối cùng của tất cả các tên
# được gắn nhãn và tạo mảng mới với chữ cái cuối cùng của mỗi tên và nhãn được liên kết.

# %%
labeled_names = []

for name in male_names:
    labeled_names.append((name[-1], 'male'))

for name in female_names:
    labeled_names.append((name[-1], 'female'))

print(labeled_names[:20])
# Out:
# [('r', 'male'), ('n', 'male'), ('y', 'male'), ('e', 'male'), ('t', 'male'), ('t', 'male'), ('y', 'male'), ('l', 'male'), ('l', 'male'), ('m', 'male'), ('h', 'male'), ('e', 'male'), ('l', 'male'), ('d', 'male'), ('r', 'male'), ('m', 'male'), ('m', 'male'), ('e', 'male'), ('r', 'male'), ('m', 'male')]
